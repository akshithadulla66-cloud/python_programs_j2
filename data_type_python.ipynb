# %% [markdown]
# # data types in python
# 1.different vatype of vwlues assignted to variable
# 2.basically 3 data types in python
# 3.int(integer) - numerical values like 1,2,3,4.....n
# 4.str(string) - charecters exampler "abcd" , 'ghjk' , "qwerty"
# 5.float(decimals) - numercial with decimals - 10.25,100.25,125.35...

# %%
name = "akshitha"
age = 16
salary=100023.25
data="123"
print(name)
print(age)
print(salary)
print(data)
print(type(name))
print(type(age))
print(type(salary))
print(type(data))
# Out:
# akshitha
# 16
# 100023.25
# 123
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
# concatenations
a=100
b=200
print(a+b)

# %%
n1="python"
n2="programming"
print(a+b)

# %%
a=100
b="300"
print(a+int(b))
# Out:
# 400
