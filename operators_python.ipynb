# %% [markdown]
# # operators in python
#
# ## 6 types of operators in python
# 1. arithematic operators
# 2. assignment operators
# 3. comparision operators
# 4. logical operators
# 5. membership

# %%
# arithematics operators - +,-,*,/,//,%
a=10
b=20
c=30
d=40
print(a+b)
print(b-c)
print(b*d)
print(d/a)
print(d//a)
print(d%a)
# Out:
# 30
# -10
# 800
# 4.0
# 4
# 0

# %%
#assingment operators - +=,-=,*=,/=,//=,%=
a=100
a+=500
print(a)
# Out:
# 600

# %%
c=50
c*=100
print(c)
# Out:
# 5000

# %%
 # comparision operators - >,<,>=.<=,==,!=
 a=10 
 b=20
 c=20
 d=30
 print(a>b)
 print(b==c)
 print(b!=c)
 print(b>=a)
 print(b<=a)
# Out:
# False
# True
# False
# True
# False

# %%
# logical operator - and,or,not
"""
and - both conditions are true then results is ture , rest cast if flase
or - either one conddition is ture the results is ture , rest case results is flase
T T = T
T F = F
F T = F
F F = F
or truth table
T T = T
T F = T
F T = T
F F = F 
"""

a=10
b=20
c=20
d=30
print(a>b and b==c)
print(a<b and c==b) 
print(a>b or b==c)
print(not a>b and b==c)
# Out:
# False
# True
# True
# True

# %%
# membership operator - in, not in 
# validating members are present in that sequence or group
names=["akshitha","niharika","navya","jaswini"]
print("akshitha" in names)
print("Niharika"not in names)
print("Akshitha"not in names)
print("akshitha" in names)
# Out:
# True
# True
# True
# True

# %%
# indentity operators - is, is not
a=10000
b=10000
print(a is b)
print(id(a))
print(id(b))
# Out:
# False
# 2109928086832
# 2109928086672

# %%
a=10
b=10
print(a is b)
print(id(a))
print(id(d))
