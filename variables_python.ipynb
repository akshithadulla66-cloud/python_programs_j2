# %% [markdown]
# # variables in python
# 1.variables is memory allocation to a value
# 2.examples are 'name="akshitha" 'age=16'

# %%
name="akshitha"
age=16
salary=10000.65
print(name)
print(age)
print(salary)
# Out:
# akshitha
# 16
# 10000.65

# %% [markdown]
# # key points to define variables
# 1. variables does not start with digit
# 2. variables does not allowed special characters
# 3. do not use keyords as a variables

# %%
1name="akshitha"
print(1name)
# Out:
#   Cell In[9], line 1
#     1name="akshitha"
#     ^
# SyntaxError: invalid decimal literal

# %%
first@name="akshitha"
print(first@name)
# Out:
#   Cell In[8], line 1
#     first@name="akshitha"
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
first_name="gowtham"
print(first_name)
# Out:
# gowtham

# %%
for = "akshitha"
print(for)
# Out:
#   Cell In[10], line 1
#     for = "akshitha"
#         ^
# SyntaxError: invalid syntax

# %%
for1="akshitha"
print(for1)
# Out:
# akshitha
