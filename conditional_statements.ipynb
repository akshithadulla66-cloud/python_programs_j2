# %% [markdown]
# # conditional statements in python
# 1.python have 4 types of conditional statements
# 2.`if` stament
# 3. `elif` statement
# 4.`else`statement
# 5.`nested` statement
#
#
# ```python - if
# if (condition ): #if condition true inside statements are running
#     statement1
#     statements...
#  ```
#
#  ```python - if,else
#  if (condition): # if condition true inside statements are running
#      statement1
#      statement2...n
#  else: # if condition fails its went to else statement and print inside statements
#      statement1
#      statement2...n
# ```
#
# ```python - if,elif,else
# if (condition):
#     statements
# elif(condition):
#     statements
# elif(condition):
#     statements
# else:
#     statements
# ```

# %%
# write a program to find the given number is even number?
number = int(input(" enter number here:"))
if(number%2==0):
  print(number,"is even number")
# Out:
#  enter number here: 76
# 76 is even number

# %%
# write a program to find the given number is even number or odd number?
num = int(input("please enter number here:"))
if (num%2 == 1):
    print(num,"is odd number")
else:
    print(num,"is even number")
# Out:
# please enter number here: 78
# 78 is even number

# %%
# write a programto find the given number is positive or zero?
n = int (input("please enter number here:"))
if(n<0):
    print(n,"is negative number")
elif (n>0):
    print(n,"is positive number")
else:
    print(n,"is zero")
# Out:
# please enter number here: -45
# -45 is negative number

# %%
#write a program to find the largest number from three number?
v1 = int(input("enter first number here:"))
v2 = int(input("enter second number here:"))
v3 = int(input("enter third number here:"))
if (v1>=v2 and v1>=v3):
    print(v1,"is the largest number")
elif (v2>=v1 and v2>=v3):
    print(v2,"is the largest number")
else:
    print(v3,"is the largest number")
# Out:
# enter first number here: 100
# enter second number here: 100
# enter third number here: 90
# 100 is the largest number

# %%
"""
write a program to find the grades based on students markets
1. if marks in between 80 to 100 - A Grande
2. if makes in between 60 to 79 - B Grande
3. if markes in between 40 to 59 - C Grande
4. if markes in between 25 to 39 _ D Grande
5. if makes in between 0 to 24 - fail
6. if other than above marks output is - please enter correct marks
"""
marks = int(input("enter student marks here:"))
if (marks>=80 and marks<=100):
    print(makes,"A Grade")
elif(marks>=60 and marks<=79):
    print(marks,"B Grande")
elif(marks>=40 and markes<=59):
    print(marks,"C Grande")
elif(marks>=25 and marks<=239):
    print(marks,"D Grade")
elif(marks>=0 and marks<=24):
    print(marks,"is Fail")
else:
    print("please enter correct marks")
# Out:
# enter student marks here: 36
# 36 D Grade

# %%
#write a program to valid login credential using conditional statements
username=str(input("please enter username here:"))
if (username=="siva@123"):
    print("username is valid")
    password=str(input("please enter password here:"))
    if(password=="sivaji@12345"):
        print("user crednetilas successfully valid")              
    else:
        print("password is invalid")
else:
     print("username is invalid")
# Out:
# please enter username here: dfgh
# username is invalid
